# %% [markdown]
# # Data Science Intern @ LetsGrowMore Virtual Internship
# ## Name: Shubham Shrimant Shende.
# # Task 4:- Image to Pencil Sketch With Python

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Read the Image in RBG Format

# %%
img = cv2.imread("Image2.jpg")
img = cv2.resize(img,(250,300))
RBG_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
display(Image.fromarray(RBG_img))
# Out:
# <PIL.Image.Image image mode=RGB size=250x300 at 0x15B48EA8520>

# %% [markdown]
#   ## RBG Image into Greyscale Image(White and Black Photo)

# %%
grey_img= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grey_img))
# Out:
# <PIL.Image.Image image mode=L size=250x300 at 0x15B30A357F0>

# %% [markdown]
#   ## Inverted Greyscale Image (Negative Image)

# %%
inverted_grey_img=255-grey_img
display(Image.fromarray(inverted_grey_img))
# Out:
# <PIL.Image.Image image mode=L size=250x300 at 0x15B51139CD0>

# %% [markdown]
# ## Convert into Negative image

# %%
Negative_img = cv2.bitwise_not(grey_img)
display(Image.fromarray(Negative_img))
# Out:
# <PIL.Image.Image image mode=L size=250x300 at 0x15B30AB0820>

# %% [markdown]
# ## Smoothen the image

# %%
Smooth_img = cv2.GaussianBlur(Negative_img, (5,5), 0 ,0)
display(Image.fromarray(Smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=250x300 at 0x15B30A9AD90>

# %% [markdown]
#  ## Convert into pencil sketch

# %%
invert_blur= 255 - Smooth_img
Pencil_Sketch = cv2.divide(grey_img,invert_blur,scale=250.0)
display(Image.fromarray(Pencil_Sketch))
# Out:
# <PIL.Image.Image image mode=L size=250x300 at 0x15B51139D90>

# %% [markdown]
# ## Combination Of Original And Pencil Sketch Image

# %%
display(Image.fromarray(RBG_img))
display(Image.fromarray(Pencil_Sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=250x300 at 0x15B30A9AD90>
# <PIL.Image.Image image mode=L size=250x300 at 0x15B30AB08B0>

# %% [markdown]
# # Thank You
